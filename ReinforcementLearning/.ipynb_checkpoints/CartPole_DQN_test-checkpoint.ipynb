# %%
import gym
import numpy as np

from DeepQNetwork import DeepQNetwork

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped

print(env.action_space)
print(env.observation_space)
print(env.observation_space.high)
print(env.observation_space.low)

n_features = env.observation_space.shape[0]
n_actions = env.action_space.n

dqn = DeepQNetwork(n_actions, n_features,
                   e_greedy=0.9,
                   reward_decay=0.9, 
                   memory_size=500, 
                   batch_size=100, 
                   update_weights=300)


total_steps = 0
for i_episode in range(300):
    obs = env.reset()
    ep_r = 0
    while(True):
        env.render()
        action = dqn.choose_action(obs)
        obs_, reward, done, info = env.step(action)
        
        # the smaller theta and closer to center the better
        x, x_dot, theta, theta_dot = obs_
        r1 = (env.x_threshold - abs(x))/env.x_threshold - 0.8
        r2 = (env.theta_threshold_radians - abs(theta))/env.theta_threshold_radians - 0.5
        reward = r1 + r2
        
        dqn.store_transition(obs, action, reward, obs_)
        
        ep_r += reward
        if total_steps > 500:
            dqn.model_train()
            
        if done or ep_r > 200:
            print('episode: ', i_episode,
                  'ep_r: ', round(ep_r, 2))
            break
            
        obs = obs_
        total_steps += 1
env.close()
# Out:
# Discrete(2)
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]
# [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]
# episode:  0 ep_r:  17.03
# episode:  1 ep_r:  14.36
# episode:  2 ep_r:  6.98
# episode:  3 ep_r:  23.8
# episode:  4 ep_r:  7.52
# episode:  5 ep_r:  10.27
# episode:  6 ep_r:  7.37
# episode:  7 ep_r:  21.01
# episode:  8 ep_r:  39.54
# episode:  9 ep_r:  6.29
# episode:  10 ep_r:  20.02
# episode:  11 ep_r:  12.83
# episode:  12 ep_r:  8.18
# episode:  13 ep_r:  6.4
# episode:  14 ep_r:  54.66
# episode:  15 ep_r:  6.13
# Update weights!
# episode:  16 ep_r:  24.96
# episode:  17 ep_r:  24.35
# episode:  18 ep_r:  16.1
# episode:  19 ep_r:  9.4
# Update weights!
# episode:  20 ep_r:  44.28
# episode:  21 ep_r:  44.44
# Update weights!
# episode:  22 ep_r:  92.98
# Update weights!
# episode:  23 ep_r:  86.2
# Update weights!
# episode:  24 ep_r:  77.84
# episode:  25 ep_r:  62.73
# Update weights!
# episode:  26 ep_r:  56.4
# Update weights!
# episode:  27 ep_r:  200.32
# episode:  28 ep_r:  48.67
# Update weights!
# episode:  29 ep_r:  22.65
# Update weights!
# episode:  30 ep_r:  200.1
# Update weights!
# episode:  31 ep_r:  200.37
# Update weights!
# episode:  32 ep_r:  200.4
# Update weights!
# episode:  33 ep_r:  200.28
# Update weights!
# episode:  34 ep_r:  151.18
# Update weights!
# episode:  35 ep_r:  200.44
# Update weights!
# episode:  36 ep_r:  54.32
# Update weights!
# episode:  37 ep_r:  200.21
# Update weights!
# episode:  38 ep_r:  85.39
# episode:  39 ep_r:  38.3
# Update weights!
# episode:  40 ep_r:  72.1
# Update weights!
# episode:  41 ep_r:  174.76
# Update weights!
# episode:  42 ep_r:  200.56
# Update weights!
# episode:  43 ep_r:  200.55
# Update weights!
# episode:  44 ep_r:  200.11
# Update weights!
# episode:  45 ep_r:  200.13
# Update weights!
# Update weights!
# episode:  46 ep_r:  148.06
# Update weights!
# episode:  47 ep_r:  200.1
# Update weights!
# episode:  48 ep_r:  165.09
# Update weights!
# episode:  49 ep_r:  200.29
# Update weights!
# Update weights!
# episode:  50 ep_r:  128.61
# Update weights!
# episode:  51 ep_r:  200.32
# Update weights!
# episode:  52 ep_r:  200.04
# Update weights!
# episode:  53 ep_r:  137.47
# Update weights!
# episode:  54 ep_r:  125.3
# Update weights!
# Update weights!
# episode:  55 ep_r:  148.21
# Update weights!
# episode:  56 ep_r:  157.5
# Update weights!
# episode:  57 ep_r:  200.48
# Update weights!
# episode:  58 ep_r:  200.27
# Update weights!
# episode:  59 ep_r:  200.2
# Update weights!
# episode:  60 ep_r:  200.44
# Update weights!
# episode:  61 ep_r:  200.15
# Update weights!
# episode:  62 ep_r:  200.04
# Update weights!
# episode:  63 ep_r:  200.14
# Update weights!
# episode:  64 ep_r:  200.54
# Update weights!
# Update weights!
# episode:  65 ep_r:  200.13
# Update weights!
# episode:  66 ep_r:  200.54
# Update weights!
# episode:  67 ep_r:  200.1
# Update weights!
# episode:  68 ep_r:  200.31
# Update weights!
# episode:  69 ep_r:  200.01
# Update weights!
# episode:  70 ep_r:  200.06
# Update weights!
# episode:  71 ep_r:  200.65
# Update weights!
# episode:  72 ep_r:  200.49
# Update weights!
# episode:  73 ep_r:  200.43
# Update weights!
# episode:  74 ep_r:  200.26
# Update weights!
# episode:  75 ep_r:  200.4
# Update weights!
# Update weights!
# episode:  76 ep_r:  200.38
# Update weights!
# episode:  77 ep_r:  200.16
# Update weights!
# episode:  78 ep_r:  200.04
# Update weights!
# episode:  79 ep_r:  200.64
# Update weights!
# episode:  80 ep_r:  200.32
# Update weights!
# episode:  81 ep_r:  200.39
# Update weights!
# episode:  82 ep_r:  200.23
# Update weights!
# episode:  83 ep_r:  200.3
# Update weights!
# episode:  84 ep_r:  200.12
# Update weights!
# episode:  85 ep_r:  200.31
# Update weights!
# episode:  86 ep_r:  200.41
# Update weights!
# episode:  87 ep_r:  200.3
# Update weights!
# Update weights!
# episode:  88 ep_r:  200.23
# Update weights!
# episode:  89 ep_r:  200.29
# Update weights!
# episode:  90 ep_r:  200.27
# Update weights!
# episode:  91 ep_r:  200.62
# Update weights!
# episode:  92 ep_r:  200.16
# Update weights!
# episode:  93 ep_r:  200.4
# Update weights!
# episode:  94 ep_r:  200.05
# Update weights!
# episode:  95 ep_r:  200.4
# Update weights!
# episode:  96 ep_r:  200.47
# Update weights!
# episode:  97 ep_r:  200.34
# Update weights!
# episode:  98 ep_r:  200.28
# Update weights!
# episode:  99 ep_r:  200.45
# Update weights!
# Update weights!
# episode:  100 ep_r:  200.31
# Update weights!
# episode:  101 ep_r:  200.26
# Update weights!
# episode:  102 ep_r:  200.04
# Update weights!
# episode:  103 ep_r:  200.13
# Update weights!
# episode:  104 ep_r:  200.13
# Update weights!
# episode:  105 ep_r:  200.54
# Update weights!
# episode:  106 ep_r:  200.01
# Update weights!
# episode:  107 ep_r:  200.06
# Update weights!
# episode:  108 ep_r:  200.22
# Update weights!
# episode:  109 ep_r:  200.04
# Update weights!
# episode:  110 ep_r:  200.12
# Update weights!
# Update weights!
# episode:  111 ep_r:  200.45
# Update weights!
# episode:  112 ep_r:  200.28
# Update weights!
# episode:  113 ep_r:  200.21
# Update weights!
# episode:  114 ep_r:  200.38
# Update weights!
# episode:  115 ep_r:  200.15
# Update weights!
# episode:  116 ep_r:  200.08
# Update weights!
# episode:  117 ep_r:  200.03
# Update weights!
# Update weights!
# episode:  118 ep_r:  200.4
# Update weights!
# episode:  119 ep_r:  200.25
# Update weights!
# episode:  120 ep_r:  200.38
# Update weights!
# episode:  121 ep_r:  200.04
# Update weights!
# episode:  122 ep_r:  200.39
# Update weights!
# episode:  123 ep_r:  200.05
# Update weights!
# episode:  124 ep_r:  200.29
# Update weights!
# episode:  125 ep_r:  200.15
# Update weights!
# episode:  126 ep_r:  200.04
# Update weights!
# episode:  127 ep_r:  200.4
# Update weights!
# episode:  128 ep_r:  200.17
# Update weights!
# episode:  129 ep_r:  200.32
# Update weights!
# episode:  130 ep_r:  200.52
# Update weights!
# episode:  131 ep_r:  200.15
# Update weights!
# Update weights!
# episode:  132 ep_r:  200.44
# Update weights!
# episode:  133 ep_r:  200.08
# Update weights!
# episode:  134 ep_r:  200.07
# Update weights!
# episode:  135 ep_r:  200.4
# Update weights!
# episode:  136 ep_r:  200.3
# Update weights!
# episode:  137 ep_r:  200.22
# Update weights!
# episode:  138 ep_r:  200.28
# Update weights!
# episode:  139 ep_r:  200.28
# Update weights!
# Update weights!
# episode:  140 ep_r:  160.16
# Update weights!
# episode:  141 ep_r:  200.5
# Update weights!
# episode:  142 ep_r:  200.16
# Update weights!
# episode:  143 ep_r:  200.17
# Update weights!
# episode:  144 ep_r:  200.48
# Update weights!
# episode:  145 ep_r:  200.36
# Update weights!
# episode:  146 ep_r:  200.39
# Update weights!
# episode:  147 ep_r:  200.46
# Update weights!
# episode:  148 ep_r:  200.55
# Update weights!
# episode:  149 ep_r:  200.18
# Update weights!
# Update weights!
# episode:  150 ep_r:  145.23
# Update weights!
# episode:  151 ep_r:  200.33
# Update weights!
# episode:  152 ep_r:  181.07
# Update weights!
# episode:  153 ep_r:  200.39
# Update weights!
# Update weights!
# episode:  154 ep_r:  200.1
# Update weights!
# episode:  155 ep_r:  200.14
# Update weights!
# episode:  156 ep_r:  200.13
# Update weights!
# episode:  157 ep_r:  200.06
# Update weights!
# episode:  158 ep_r:  200.12
# Update weights!
# episode:  159 ep_r:  129.62
# Update weights!
# episode:  160 ep_r:  200.01
# Update weights!
# episode:  161 ep_r:  200.25
# Update weights!
# episode:  162 ep_r:  200.51
# Update weights!
# episode:  163 ep_r:  200.54
# Update weights!
# Update weights!
# episode:  164 ep_r:  172.98
# Update weights!
# episode:  165 ep_r:  200.16
# Update weights!
# episode:  166 ep_r:  200.01
# Update weights!
# episode:  167 ep_r:  200.22
# Update weights!
# Update weights!
# episode:  168 ep_r:  200.21
# Update weights!
# episode:  169 ep_r:  200.18
# Update weights!
# episode:  170 ep_r:  200.56
# Update weights!
# episode:  171 ep_r:  200.05
# Update weights!
# episode:  172 ep_r:  200.01
# Update weights!
# Update weights!
# episode:  173 ep_r:  200.29
# Update weights!
# episode:  174 ep_r:  200.1
# Update weights!
# episode:  175 ep_r:  200.16
# Update weights!
# episode:  176 ep_r:  200.03
# Update weights!
# episode:  177 ep_r:  200.02
# Update weights!
# episode:  178 ep_r:  200.52
# Update weights!
# episode:  179 ep_r:  200.47
# Update weights!
# episode:  180 ep_r:  200.09
# Update weights!
# episode:  181 ep_r:  200.47
# Update weights!
# episode:  182 ep_r:  200.27
# Update weights!
# Update weights!
# episode:  183 ep_r:  200.06
# Update weights!
# episode:  184 ep_r:  200.42
# Update weights!
# episode:  185 ep_r:  200.1
# Update weights!
# episode:  186 ep_r:  200.39
# Update weights!
# episode:  187 ep_r:  200.29
# Update weights!
# episode:  188 ep_r:  200.37
# Update weights!
# episode:  189 ep_r:  200.58
# Update weights!
# episode:  190 ep_r:  200.05
# Update weights!
# episode:  191 ep_r:  200.35
# Update weights!
# episode:  192 ep_r:  200.57
# Update weights!
# episode:  193 ep_r:  200.6
# Update weights!
# episode:  194 ep_r:  200.0
# Update weights!
# Update weights!
# episode:  195 ep_r:  200.08
# Update weights!
# episode:  196 ep_r:  200.44
# Update weights!
# episode:  197 ep_r:  200.6
# Update weights!
# episode:  198 ep_r:  200.02
# Update weights!
# episode:  199 ep_r:  200.06
# Update weights!
# episode:  200 ep_r:  200.19
# Update weights!
# Update weights!
# episode:  201 ep_r:  171.16
# Update weights!
# episode:  202 ep_r:  200.29
# Update weights!
# episode:  203 ep_r:  200.08
# Update weights!
# episode:  204 ep_r:  200.09
# Update weights!
# episode:  205 ep_r:  160.96
# Update weights!
# Update weights!
# episode:  206 ep_r:  200.19
# Update weights!
# episode:  207 ep_r:  200.14
# Update weights!
# episode:  208 ep_r:  200.36
# Update weights!
# episode:  209 ep_r:  200.37
# Update weights!

# %%
env.close()

# %%
import time
import numpy as np
import gym
from keras.models import load_model

model = load_model('model/CartPoleModel')

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped
n_round = 0
while(True):
    n_round += 1
    env.render()
    obs = env.reset()
    actions_q = model.predict(obs[np.newaxis, :])
    action = np.argmax(actions_q)
    obs_, reward, done, info = env.step(action)
    if done:
        print("Game over!(round %d)" % n_round)
        break
    if n_round > 200:
        print("Play too long!(round 200)")
        break
    time.sleep(0.08)
env.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py in gather(***failed resolving arguments***)
#    4675     # without introducing a circular dependency.
# -> 4676     return params.sparse_read(indices, name=name)
#    4677   except AttributeError:
#
# AttributeError: 'Tensor' object has no attribute 'sparse_read'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-74c942142ac8> in <module>
#       6     env.render()
#       7     obs = env.reset()
# ----> 8     actions_q = model.predict(obs[np.newaxis, :])
#       9     action = np.argmax(actions_q)
#      10     obs_, reward, done, info = env.step(action)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1567     with self.distribute_strategy.scope():
#    1568       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1569       data_handler = data_adapter.DataHandler(
#    1570           x=x,
#    1571           batch_size=batch_size,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1103
#    1104     adapter_cls = select_data_adapter(x, y)
# -> 1105     self._adapter = adapter_cls(
#    1106         x,
#    1107         y,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     362     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     363
# --> 364     dataset = self.slice_inputs(indices_dataset, inputs)
#     365
#     366     if shuffle == "batch":
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     394       return nest.map_structure(lambda d: array_ops.gather(d, i, axis=0), data)
#     395
# --> 396     dataset = dataset.map(
#     397         grab_batch, num_parallel_calls=dataset_ops.AUTOTUNE)
#     398
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic)
#    1695       return MapDataset(self, map_func, preserve_cardinality=True)
#    1696     else:
# -> 1697       return ParallelMapDataset(
#    1698           self,
#    1699           map_func,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    4078     self._input_dataset = input_dataset
#    4079     self._use_inter_op_parallelism = use_inter_op_parallelism
# -> 4080     self._map_func = StructuredFunctionWrapper(
#    4081         map_func,
#    4082         self._transformation_name(),
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3369       with tracking.resource_tracker_scope(resource_tracker):
#    3370         # TODO(b/141462134): Switch to using garbage collection.
# -> 3371         self._function = wrapper_fn.get_concrete_function()
#    3372         if add_to_graph:
#    3373           self._function.add_to_graph(ops.get_default_graph())
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    2936       **kwargs: inputs to specialize on.
#    2937     """
# -> 2938     graph_function = self._get_concrete_function_garbage_collected(
#    2939         *args, **kwargs)
#    2940     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2904       args, kwargs = None, None
#    2905     with self._lock:
# -> 2906       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2907       seen_names = set()
#    2908       captured = object_identity.ObjectIdentitySet(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3063     arg_names = base_arg_names + missing_arg_names
#    3064     graph_function = ConcreteFunction(
# -> 3065         func_graph_module.func_graph_from_py_func(
#    3066             self._name,
#    3067             self._python_function,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in wrapper_fn(*args)
#    3362           attributes=defun_kwargs)
#    3363       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 3364         ret = _wrapper_helper(*args)
#    3365         ret = structure.to_tensor_list(self._output_structure, ret)
#    3366         return [ops.convert_to_tensor(t) for t in ret]
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in _wrapper_helper(*args)
#    3297         nested_args = (nested_args,)
#    3298
# -> 3299       ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#    3300       # If `func` returns a list of tensors, `nest.flatten()` and
#    3301       # `ops.convert_to_tensor()` would conspire to attempt to stack
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     253       try:
#     254         with conversion_ctx:
# --> 255           return converted_call(f, args, kwargs, options=options)
#     256       except Exception as e:  # pylint:disable=broad-except
#     257         if hasattr(e, 'ag_error_metadata'):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     530
#     531   if not options.user_requested and conversion.is_whitelisted(f):
# --> 532     return _call_unconverted(f, args, kwargs, options)
#     533
#     534   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     337
#     338   if kwargs is not None:
# --> 339     return f(*args, **kwargs)
#     340   return f(*args)
#     341
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in grab_batch(i, data)
#     392
#     393     def grab_batch(i, data):
# --> 394       return nest.map_structure(lambda d: array_ops.gather(d, i, axis=0), data)
#     395
#     396     dataset = dataset.map(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in <lambda>(d)
#     392
#     393     def grab_batch(i, data):
# --> 394       return nest.map_structure(lambda d: array_ops.gather(d, i, axis=0), data)
#     395
#     396     dataset = dataset.map(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py in gather(***failed resolving arguments***)
#    4676     return params.sparse_read(indices, name=name)
#    4677   except AttributeError:
# -> 4678     return gen_array_ops.gather_v2(params, indices, axis, name=name)
#    4679
#    4680
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py in gather_v2(params, indices, axis, batch_dims, name)
#    3855     batch_dims = 0
#    3856   batch_dims = _execute.make_int(batch_dims, "batch_dims")
# -> 3857   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    3858         "GatherV2", params=params, indices=indices, axis=axis,
#    3859                     batch_dims=batch_dims, name=name)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     351   inputs = []
#     352   input_types = []
# --> 353   with g.as_default(), ops.name_scope(name) as scope:
#     354
#     355     # Perform input type inference
#
# ~/anaconda3/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in inner_cm()
#     402       # Inherit the auto_cast_variable_read_dtype, since this should not change
#     403       # inside a function.
# --> 404       old_auto_cast_var_read_dtype = self._auto_cast_variable_read_dtype
#     405       self._auto_cast_variable_read_dtype = graph._auto_cast_variable_read_dtype
#     406       # pylint: enable=protected-access
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _auto_cast_variable_read_dtype(self)
#    5126       The dtype that instances of `AutoCastVariable` will be casted to.
#    5127     """
# -> 5128     dtype = getattr(self._thread_local, "_auto_cast_variable_read_dtype", None)
#    5129     if dtype is None:
#    5130       self._thread_local._auto_cast_variable_read_dtype = None  # pylint: disable=protected-access
#
# KeyboardInterrupt:
